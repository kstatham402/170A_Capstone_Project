# %% [markdown]
# # Metabolic History and DM Medication Initiation
# Which pts had baseline DM, which ones were started on DM meds (which agents were they on? Any stats significant differences here and illustrate)

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import chi2_contingency, ttest_ind
from sklearn.model_selection import StratifiedKFold, cross_validate
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix

seed = 42
n_folds = 5
df = pd.read_csv('../../data/processed/cardio_onc_prostate_04cleaned.csv')
